# %%
from src.data_preprocessing import clean_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.data_preprocessing import clean_data
#
# ModuleNotFoundError: No module named 'src'
